# %%
import pandas as pd
import numpy as np
import YahooFinance as yf
import tsmom as tm
from importlib import reload
reload(tm)
import datetime as dt
# Out:
# /Users/ravikohli/opt/anaconda3/lib/python3.9/site-packages/pyfolio/pos.py:26: UserWarning:
#
# Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.

# %%
ticks = ['TSLA']
start = dt.datetime(2020,1,1)
data = tm.get_yahoo_data(ticks, start= start)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Out:
# [*********************100%***********************]  2 of 2 completed
#              Adj Close                   Close                    High  \
#                   AAPL        TSLA        AAPL        TSLA        AAPL
# Date
# 2020-01-02   73.894325   86.052002   75.087502   86.052002   75.150002
# 2020-01-03   73.175919   88.601997   74.357498   88.601997   75.144997
# 2020-01-06   73.759010   90.307999   74.949997   90.307999   74.989998
# 2020-01-07   73.412132   93.811996   74.597504   93.811996   75.224998
# 2020-01-08   74.593048   98.428001   75.797501   98.428001   76.110001
# ...                ...         ...         ...         ...         ...
# 2022-04-25  162.880005  998.020020  162.880005  998.020020  163.169998
# 2022-04-26  156.800003  876.419983  156.800003  876.419983  162.339996
# 2022-04-27  156.570007  881.510010  156.570007  881.510010  159.789993
# 2022-04-28  163.639999  877.510010  163.639999  877.510010  164.520004
# ...
